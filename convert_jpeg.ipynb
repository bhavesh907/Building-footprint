# %%
import os
from PIL import Image

yourpath = '/media/monster/New Volume1/AerialImageDataset/train/gt'
root1 = '/media/monster/New Volume1/AerialImageDataset/train/gt_jpeg'
for root, dirs, files in os.walk(yourpath, topdown=False):
#     print("printing root",root)
    for name in files:
        print(os.path.join(root, name))
#         print("first loop")
        if os.path.splitext(os.path.join(root, name))[1].lower() == ".tif":
#             print("second loop")
            if os.path.isfile(os.path.splitext(os.path.join(root, name))[0] + ".jpg"):
                print "A jpeg file already exists for %s" % name
            # If a jpeg is *NOT* present, create one from the tiff.
            else:
                outfile = os.path.splitext(os.path.join(root1, name))[0] + ".jpg"
#                 print("outname",outfile)
                try:
#                     pass
                    im = Image.open(os.path.join(root, name))
                    print "Generating jpeg for %s" % name
                    im.thumbnail(im.size)
                    im.save(outfile, "JPEG", quality=10)
                    print("saving jpeg")
                except Exception, e:
                    print e
# Out:
# /media/monster/New Volume1/AerialImageDataset/train/gt/austin1.tif
# Generating jpeg for austin1.tif
# saving jpeg
# /media/monster/New Volume1/AerialImageDataset/train/gt/austin1.tif.aux.xml
# /media/monster/New Volume1/AerialImageDataset/train/gt/austin10.tif
# Generating jpeg for austin10.tif
# saving jpeg
# /media/monster/New Volume1/AerialImageDataset/train/gt/austin11.tif
# Generating jpeg for austin11.tif
# saving jpeg
# /media/monster/New Volume1/AerialImageDataset/train/gt/austin12.tif
# Generating jpeg for austin12.tif
# saving jpeg
# /media/monster/New Volume1/AerialImageDataset/train/gt/austin13.tif
# Generating jpeg for austin13.tif
# saving jpeg
# /media/monster/New Volume1/AerialImageDataset/train/gt/austin14.tif
# Generating jpeg for austin14.tif
# saving jpeg
# /media/monster/New Volume1/AerialImageDataset/train/gt/austin15.tif
# Generating jpeg for austin15.tif
# saving jpeg
# /media/monster/New Volume1/AerialImageDataset/train/gt/austin16.tif
# ...
